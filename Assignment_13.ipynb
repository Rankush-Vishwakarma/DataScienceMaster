# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.   Excel spreadsheet store not only the data but the opeartion, macros, formulas and others in the same , while CSV  file is just the comma seperated text file and it only store data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# csv.reader() is used to read the csv file data, it use open file object in reading mode it , has another parameter as delimeter whihc signifies how the uer want to delimite the file using space, tab or whatever. while The csv.writer() function returns a writer object that converts the user's data into a delimited string. This string can later be used to write into CSV files using the writerow() function.

# %% [markdown]
# ```
# reader = csv.reader(file_obj_in_reading_mode, delimiter = '\t')
# writer = csv.writer(file_obj_in_writing_mode)
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# from CSv module the reader and writeer object need to be opened.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The csv.writer().writerow method takes an iterable i.e. list as an argument and write it into the file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A delimiter is the character that appears between cells on a row. By default,the delimiter for a CSV file is a comma while A line terminator is the character that comes at the end of a row. By default, the line terminator is a newline. delimiters can be space, tab, 2 space, or other ,while it is same true for newline charcter it can be '\n' or other.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# While working with json files the loads() function used to return the python data structure of json strignor data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From json module dump() method used to convert a python data structure and return resective json object.
