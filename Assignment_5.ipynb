# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
empty_dict = {}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dict_2 = {'foo':42}
print(dict_2['foo'])
# Out:
# 42

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# dictionaries are accessed via keys and not via their position, while in list the items to be accessed by the index position.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# It will throw an error as key not found since there is no key with the name 'foo' available in the dictionary.

# %%
spam = {'bar':100}
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-cea1cd791e68> in <module>()
#       1 spam = {'bar':100}
# ----> 2 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
spam = {'cat':10,'dog':10000,'rabbit':2}

if 'cat' in spam:
  print('yes present')
# Out:
# yes present

# %%
if 'cat' in spam.keys():
  print('yes present')
# Out:
# yes present

# %% [markdown]
# we can clearly see that both the operation are right simply because be default the spam take keys are list so wheather we use direct spam or spam.keys the rsult would be same.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
spam = {1:'cat',2:'dog',3:'rabbit'}

if 'cat' in spam:
  print('yes present')

# %% [markdown]
# Here since using spam it will take all the keys in the dictionary as the list and serach for the item but since 'cat' is not present as key it is not preinting anything.

# %%
if 'cat' in spam.values():
  print('yes present')
# Out:
# yes present

# %% [markdown]
# But, here dictionary is printing because we are checking in the the spam value.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
if 'color' not in spam:
  spam['color'] = 'black'

# %% [markdown]
# we can use tab in order to fix the identation problem and Ctrl + ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# we can use pprint module and pprint function from that in order to pretty print.

# %%
from pprint import pprint

dct_arr = [
  {'Name': 'rankush', 'Age': '23', 'india': 'madhyapradesh'},
  {'Name': 'ram', 'Age': '44', 'india': 'rewa'}
]
pprint(dct_arr)
# Out:
# [{'Age': '23', 'Name': 'rankush', 'india': 'madhyapradesh'},
#  {'Age': '44', 'Name': 'ram', 'india': 'rewa'}]
