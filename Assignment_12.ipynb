# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# PdfFileReader() needs to be opened in read-binary mode by passing 'rb' as the second argument to open() while PdfFileWriter() needs to be opened in write-binary mode with 'wb'.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Before obtaining the page object firstly we must check file.isEncrypted it yes then use file.decrypt(with_password) in order to decrpyt it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We need to use  pageObj.rotateClockwise(rotation_angle_value) in order to rotate it , we can pass 90 180, 270 or whatever angle value we need to rotate the page.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  A Run object is a contiguous run of text with the same style. A new Run object is needed whenever the text style changes while a document contain multiple paragrpahas and the paragrpah ojects conrains a list of one or more Run objects.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We need to use doc.paragrpahs object to get the list of all the document paragraphs.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Bold, underline , italic , strike, and outline are all run objects , it cannot be paragraph objects.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# True used to make the run object bolded and False will make it always not bolded it is not depand upon the defult settings, while None will make te object to used the styles'Bold setting.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# WE need to used docs.Document() function to make the new word document.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For addign paragrpah in the document we have to use doc.add_paragraph("Hello, there!").

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The word heading leveld can be represent from 0-4 , so there is 5 levels availble in word documents heading level.
