# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The relative path refers to the file exists in the same current working directory.
# let see I am working in  C:\Users\rvishwakar23\Desktop\data scientist> and the file file name is download.png in the same library in that case i don't need explicitly pass the whole file path.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# os.getcwd() is used to get the path of current working directory. while the os.chdir() method is used to change the current working directory and return none.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# . is the current direcotry while .. shows the parent directory.![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# C:\bacon\eggs is the dir name, while spam.txt is the base name

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# "mode" argument in open() function get three parameter as read/readlines, write, and append.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# it overwrites the existing file and starts from scratch.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The read() method passes the entire file as a string while  readlines() method provides a list of string values - one string for each line of text.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Self value Resembles a dictionary it has keys and values structure and the functionalities are also similar to the dictionary
