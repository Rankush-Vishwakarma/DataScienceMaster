# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# RGBA is css color properties it is well known as primary colors(rgb) while RGBA is the extended versiion of the primary colors , R-RED, G-GREEN, B-BLUE, A-ALPHA,
# where alpha deals with the opacity of the colors and the value ranges from 0-1. zero means fully transparent while 1 is fully opaque.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# By default the color in pillow Image method returns primary color value in order to get RGBa color value we need to first convert the image into respective RGBA pattern and after that with the help of Image_obj.getpixel(xy) we can get all four values respectively.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Box tuple is tuple with four integer edge cooredination values consists of tuple(left:x-coordinate left most, top:y-coordinate top most, right:x-coordinates right most, bottom:y-coordinate bottom edge value ).
# X and y value starts with (0,0) and ends with the width of image , and height of image in pixels.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Original image
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cropped image

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can use Image.crop function and pass the particular are i.e 100*100 image.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We have to use the imag_obj.save(file_name) in order to same the file after making changes to an image .
#
#
# ```
# cropped.save('new.png')
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ImageDraw module of the Python image processing library Pillow (PIL) provides many methods for drawing figures, such as circles, squares, and straight lines.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Image object do not have drawing method we need ImageDraw module in order to make nay kind of drawing over the image.
