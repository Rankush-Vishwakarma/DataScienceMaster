# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from datetime import date

# %%
with open('today.txt','w') as txt:
  txt.write(str(date.today()))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
with open('today.txt','r') as txt:
  print(txt.readline())
# Out:
# 2022-02-21

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from datetime import datetime, timedelta
with open('today.txt','r') as txt:
  today_string = txt.readline()

# %%
datetime.strptime(today_string,'%Y-%M-%d')
# Out:
# datetime.datetime(2022, 1, 21, 0, 2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os
print(os.listdir('.'))
# Out:
# ['.config', 'today.txt', 'sample_data']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import multiprocessing
import random 
from time import sleep
def process1():
  print('This is first process...')
def process2():
  print('This is second process...')
def process3():
  print('This is third Process...')

p1 = multiprocessing.Process(target=process1)
p2 = multiprocessing.Process(target=process2)
p3 = multiprocessing.Process(target=process3)

# starting process 1
p1.start()
# starting process 2
p2.start()
# starting process 3
p3.start()

# wait until process 1 is finished
sleep(random.randint(1,5))
p1.join()
# wait until process 2 is finished
sleep(random.randint(1,5))
p2.join()
# wait until process 2 is finished
sleep(random.randint(1,5))
p3.join()

print("done!")
# Out:
# This is first process...
# This is second process...
# This is third Process...
# done!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import datetime

DOB = datetime.datetime(2001, 8, 8)

print(DOB)
# Out:
# 2001-08-08 00:00:00

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
DOB.weekday()
# Out:
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
DOB_after_10000_days = DOB + timedelta(days=10000)
print(DOB_after_10000_days)
# Out:
# 2028-12-24 00:00:00
