# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
guess_me = 7
if guess_me < 7 :
  print('too low')
elif guess_me >7:
  print('too high')
else:
  print('just right')
# Out:
# just right

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
guess_me = 7
start = 1
while True:
  if start < guess_me:
    print('too low')
  elif(start == guess_me):
    print('found it!')
  elif(start>guess_me):
    print('oops')
    break
  else:
    pass
  start += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!
# oops

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(3,-1,-1):
  print(i)
# Out:
# 3
# 2
# 1
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
even = [i for i in range(10) if i%2 == 0]
print(even)
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
square = {i:i**2 for i in range(10)}
print(square)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
odd_numbers = {i for i in range(10) if i%2 != 0}
print(odd_numbers)
# Out:
# {1, 3, 5, 7, 9}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
genComp = ('got'+str(i) for i in range(10))
type(genComp)
# Out:
# generator

# %%
next(genComp)
# Out:
# 'got0'

# %%
next(genComp)
# Out:
# 'got1'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def good():
  return ['Harry','Ron','Hermione']
good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def get_odds():
  for i in range(10):
    if i%2 != 0:
      yield i
    else: pass

# %%
gen_odd = get_odds()
next(gen_odd)
# Out:
# 1

# %%
next(gen_odd)
# Out:
# 3

# %%
next(gen_odd)
# Out:
# 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class OopsException(Exception):
  print('Caught an oops')
  

# raising an exception 
i = 5

if i<5:
  print('did not get any exception. ')
elif i==5:
  raise OopsException
else:
  print('thankyou')
# Out:
# Caught an oops
# ---------------------------------------------------------------------------
# OopsException                             Traceback (most recent call last)
# <ipython-input-23-52ecc9b3f3e1> in <module>()
#       9   print('did not get any exception. ')
#      10 elif i==5:
# ---> 11   raise OopsException
#      12 else:
#      13   print('thankyou')
#
# OopsException:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
titles = ['Creature of Habit','Crewel Fate']
plots = ['A nun turns into a monster','A haunted yarn shop']

dictionary = dict(zip(titles, plots))
print(dictionary)
# Out:
# {'Creature of Habit': 'A nun turns into a monster', 'Crewel Fate': 'A haunted yarn shop'}
