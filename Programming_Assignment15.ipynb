# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def Question1(n):
  def generator(n):
    for i in range(n):
      if i%5 == 0 and i%7 == 0:
        yield i
  que1 =  generator(n)
  print(*que1, sep = ",")

# %%
Question1(100)
# Out:
# 0,35,70

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def Question2(n):
  def generator(n):
    for i in range(n+1):
      if i%2 == 0:
        yield i
  que2 =  generator(n)
  print(*que2, sep = ",")

# %%
Question2(10)
# Out:
# 0,2,4,6,8,10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def Question3(n):
