# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
years_list = [2001,2002,2003,2004,2005,2006]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
years_list[4] # since for first year i were 0 years or in simple it is my 0th index and if i want to get 3rd value we end to pass 4th value
# Out:
# 2005

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
years_list.pop()
# Out:
# 2006

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
things = ["mozzarella","cinderell","salmonella"]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
things[1] = things[1].capitalize()

# %%
print(things)
# Out:
# ['mozzarella', 'Cinderell', 'salmonella']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
surprise_list = ["Groucho", "Chico", "Harpo"]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
surprise_list[-1] = surprise_list[-1].lower()[::-1].capitalize()

# %%
print(surprise_list)
# Out:
# ['Groucho', 'Chico', 'Oprah']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
e2f = {'dog':'chien','cat':'chat','walrus':'morse'}
print(e2f)
# Out:
# {'dog': 'chien', 'cat': 'chat', 'walrus': 'morse'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
e2f['walrus']
# Out:
# 'morse'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
f2e = {}
for k,v in e2f.items():
  f2e[v] = k
print(f2e)
# Out:
# {'chien': 'dog', 'chat': 'cat', 'morse': 'walrus'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
f2e['chien']
# Out:
# 'dog'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
set(e2f.keys())
# Out:
# {'cat', 'dog', 'walrus'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
life ={
    'animal':
            {'cats':
             ['Henri','Grumpy','Lucy'],'octopi':'','emus':''},
       'plants':'',
       'other':''}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
life.keys()
# Out:
# dict_keys(['animal', 'plants', 'other'])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
life['animal'].keys()
# Out:
# dict_keys(['cats', 'octopi', 'emus'])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
life['animal']['cats']
