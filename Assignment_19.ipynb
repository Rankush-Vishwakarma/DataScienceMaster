# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# class
class Thing:
  pass

# printing the class .
print('class:-',Thing)

# object and printing it.
example = Thing()
print('object:-',example)
# Out:
# class:- <class '__main__.Thing'>
# object:- <__main__.Thing object at 0x7f9037064790>

# %% [markdown]
# We can see the prints are totally different , this happen because Thing is a Class while the exmple is the object of the same class and it is stored in another location.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# defining the class
class Thing2:
    letters = 'abc'

# calling for the attribute
Thing2.letters
# Out:
# 'abc'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# creating the class
class Thing3:
    def __init__(self,letter):
        self.letter = letter
    def letters(self):
        print(self.letter)

# printing the letters without making explicit object 
Thing3('xyz').letters()
# printint the letter with making class
Thingobj = Thing3('xyz')
Thingobj.letters()
# Out:
# xyz
# xyz

# %% [markdown]
# In python , class function can be called directly without making explicit object of it, but for the standard purpose we should create the object and use the functions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# creating the class
class Element:
    def __init__(self,name,symbol,number):
        self.name = name
        self.symbol = symbol
        self.number = number
    def printThem(self):
        print(self.name,self.symbol,self.number)

#creating the object 
obj = Element('Hydrogen','H',1)
obj.name
# Out:
# 'Hydrogen'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dict = {'name':'Hydrogen', 'symbol':'H','number': 1}
# using dictionary unpacking method
hydrogen = Element(**dict) 
print(hydrogen.symbol)
# Out:
# H

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# defining the class 
class Element:
    def __init__(self,name,symbol,number):
        self.name = name
        self.symbol = symbol
        self.number = number
    def dump(self):
        print(self.name,self.symbol,self.number)

# defining the method
hydrogen = Element('Hydrogen','H',1)
hydrogen.dump()
# Out:
# Hydrogen H 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# defining the class with __str__ method
class Element:
    def __init__(self,name,symbol,number):
        self.name = name
        self.symbol = symbol
        self.number = number
    def __str__(self):
        return (f'name={self.name}, symbol={self.symbol}, number={self.number}')

# definging the object
hydrogen = Element('Hydrogen','H',1)
print(hydrogen)
# Out:
# name=Hydrogen, symbol=H, number=1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # defining the element class and maing it private  and defining the getter property
# # @property is used to get the value of a private attribute without using
# # any getter methods.

# %%
class Element(): 
    def __init__(self ,name,symbol,number):
        self.__name = name
        self.__symbol = symbol
        self.__number = number
    @property
    def name(self):
        return (self.__name)
    @property
    def symbol(self):
        return (self.__symbol)
    @property
    def number(self):
        return (self.__number)

# definging the object of it
hydrogen = Element('Hydrogen','H',1)
hydrogen.name
# Out:
# 'Hydrogen'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# definging all the three classes
class Bear:
    def eats():
        print('berries')

class Rabbit:
    def eats():
        print('clover')

class Octothorpe:
    def eats():
        print('campers')

# definging all the objects
Bear.eats()
Rabbit.eats()
Octothorpe.eats()
# Out:
# berries
# clover
# campers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# definging the classeswith one method does
class Laser:
    def does(self):
        return('disitegrate')
class Claw:
    def does(self):
        return('crush')
class SmartPhone:
    def does(self):
        return('ring')
        
class Robot:
    def __init__(self):
        self.laser = Laser()
        self.claw = Claw()
        self.smartphone = SmartPhone()
    def does(self):
        return (f'Laser is {self.laser.does()}, Claw is {self.claw.does()},SmartPhone is {self.smartphone.does()}')

# %%
# definging the object and calling the method does
robo = Robot()
robo.does()
# Out:
# 'Laser is disitegrate, Claw is crush,SmartPhone is ring'
